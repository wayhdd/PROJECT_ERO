# %%
import numpy as np
import sys
sys.path.append("./scripts")
import eulerian_path as ep

# %% [markdown]
# ## Parcours du drone

# %%
# l is the list of graph
# i is the index of the sub-graph sb
paths = []
for i, sg in enumerate(l):
    print("\nSub part of Montréal n°%d" % (i + 1))
    paths.append(ep.convert_and_find_eulerian_path(sg))
    print("Eulerian Path Found")
